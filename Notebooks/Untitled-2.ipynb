# %%
import pandas as pd

# Load the data
df = pd.read_csv('ml_models/ml_data_test_10.csv')

# Check it
print(f"Shape: {df.shape}")
print(f"Companies: {df['Ticker'].unique()}")
print(f"Columns: {df.columns.tolist()}")
print(df.head())
# Out:
# Shape: (40, 51)
# Companies: ['AAPL' 'AMZN' 'CVX' 'GOOGL' 'JNJ' 'JPM' 'MSFT' 'PG' 'TSLA' 'XOM']
# ...

# %%
df
# Out:
#    Ticker                       Company                  Sector  \
# 0    AAPL                    Apple Inc.              Technology
# 1    AAPL                    Apple Inc.              Technology
# 2    AAPL                    Apple Inc.              Technology
# 3    AAPL                    Apple Inc.              Technology
# 4    AMZN              Amazon.com, Inc.       Consumer Cyclical
# 5    AMZN              Amazon.com, Inc.       Consumer Cyclical
# 6    AMZN              Amazon.com, Inc.       Consumer Cyclical
# 7    AMZN              Amazon.com, Inc.       Consumer Cyclical
# 8     CVX           Chevron Corporation                  Energy
# 9     CVX           Chevron Corporation                  Energy
# 10    CVX           Chevron Corporation                  Energy
# 11    CVX           Chevron Corporation                  Energy
# 12  GOOGL                 Alphabet Inc.  Communication Services
# 13  GOOGL                 Alphabet Inc.  Communication Services
# ...
